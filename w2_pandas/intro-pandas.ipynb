# %% [markdown]
# ## Facilitator
#
# Ali Haider - Technical Lead - GDSC Iowa State University
#
# ### Links
#
# - LinkedIn: https://www.linkedin.com/in/m-ali-haider/
# - Email: mhaider@iastate.edu
# - Github: https://github.com/allihaider
# - Medium: https://medium.com/@m.allihaider
#
#
# ---
#
# ## Topics
# 1. Series
#   * Creation
#   * Attributes
#   * Indexing
# 2. Dataframe
#   * Creation
#   * Attributes
#   * Indexing
# 3. Operations
#   * Adding and Removing columns
#   * Renaming Columns and Indices
#   * Summary Functions
#   * Maps
#   * Groupby
#   * Sorting
#   * Handling Data Types and Missing Value
#   * Combining Dataframes

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Data Structures

# %% [markdown]
# ### Series

# %% [markdown]
# An array-like object containing a sequence of values and associated labels.

# %% [markdown]
# ### Creation

# %%
series_object = pd.Series([5, 6, 7, 8, 9])

# %%
series_object
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %% [markdown]
# ### Attributes

# %%
series_object.values
# Out:
# array([5, 6, 7, 8, 9])

# %%
series_object.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# series_object.name
# series_object.index.name

# %% [markdown]
# ### Indexing

# %%
another_series_object = pd.Series([5, 6, 7, 8, 9], index=["a", "b", "c", "d", "e"])

# %%
another_series_object
# Out:
# a    5
# b    6
# c    7
# d    8
# e    9
# dtype: int64

# %%
another_series_object["b"]
# Out:
# 6

# %%
another_series_object[["a", "d", "e"]]
# Out:
# a    5
# d    8
# e    9
# dtype: int64

# %% [markdown]
# ### DataFrame

# %% [markdown]
# A table of data containing an ordered collection of columns
#
# OR
#
# A dictionary of series sharing the same indices.

# %% [markdown]
# ### Creation

# %%
data_dict = {
    "Classes" : ["AI", "Stats", "Thermodynamics"],
    "Schools" : ["CS", "Maths", "Engineering"],
    "Seniority": ["Junior", "Senior", "Sophomore"]    
    }

# %%
df = pd.DataFrame(data_dict)

# %%
# index assigned automatically
df
# Out:
#           Classes      Schools  Seniority
# 0              AI           CS     Junior
# 1           Stats        Maths     Senior
# 2  Thermodynamics  Engineering  Sophomore

# %% [markdown]
# ### Attributes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Classes', 'Schools', 'Seniority'], dtype='object')

# %% [markdown]
# ### Indexing

# %%
df["Classes"]
# Out:
# 0                AI
# 1             Stats
# 2    Thermodynamics
# Name: Classes, dtype: object

# %%
df["Classes"][2]
# Out:
# 'Thermodynamics'

# %%
df.Classes
# Out:
# 0                AI
# 1             Stats
# 2    Thermodynamics
# Name: Classes, dtype: object

# %%
df.loc[2]
# Out:
# Classes      Thermodynamics
# Schools         Engineering
# Seniority         Sophomore
# Name: 2, dtype: object

# %%
data_dict = {
    "Classes" : ["AI", "Stats", "Thermodynamics"],
    "Schools": ["CS", "Maths", "Engineering"],
    "Seniority": ["Junior", "Senior", "Sophomore"]    
    }

# %%
df = pd.DataFrame(data_dict, index=["a", "b", "c"])

# %%
df
# Out:
#           Classes      Schools  Seniority
# a              AI           CS     Junior
# b           Stats        Maths     Senior
# c  Thermodynamics  Engineering  Sophomore

# %%
df.loc["b"]
# Out:
# Classes       Stats
# Schools       Maths
# Seniority    Senior
# Name: b, dtype: object

# %%
# df.loc[1]

# %%
df.iloc[1]
# Out:
# Classes       Stats
# Schools       Maths
# Seniority    Senior
# Name: b, dtype: object

# %%
df.iloc[:, 0]
# Out:
# a                AI
# b             Stats
# c    Thermodynamics
# Name: Classes, dtype: object

# %%
df[[True, False, True]]
# Out:
#           Classes      Schools  Seniority
# a              AI           CS     Junior
# c  Thermodynamics  Engineering  Sophomore

# %% [markdown]
# ## Operations on Dataframes

# %% [markdown]
# ### Adding and Removing columns

# %%
df["Grade"] = ["A", None, "A-"]

# %%
df
# Out:
#           Classes      Schools  Seniority Grade
# a              AI           CS     Junior     A
# b           Stats        Maths     Senior  None
# c  Thermodynamics  Engineering  Sophomore    A-

# %%
del df["Grade"]

# %%
df
# Out:
#           Classes      Schools  Seniority
# a              AI           CS     Junior
# b           Stats        Maths     Senior
# c  Thermodynamics  Engineering  Sophomore

# %% [markdown]
# ### Renaming columns and indices

# %%
df.rename(columns={'Classes': 'Subjects'})
# Out:
#          Subjects      Schools  Seniority
# a              AI           CS     Junior
# b           Stats        Maths     Senior
# c  Thermodynamics  Engineering  Sophomore

# %%
df.rename(index={"a": 0, "b": 1, "c": 2})
# Out:
#           Classes      Schools  Seniority
# 0              AI           CS     Junior
# 1           Stats        Maths     Senior
# 2  Thermodynamics  Engineering  Sophomore

# %% [markdown]
# ### Summary Functions

# %% [markdown]
# Link to dataset: https://www.kaggle.com/datasets/rajyellow46/wine-quality

# %%
wine_df = pd.read_csv("winequalityN.csv")

# %%
wine_df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
wine_df["type"].describe()
# Out:
# count      6497
# unique        2
# top       white
# freq       4898
# Name: type, dtype: object

# %%
wine_df.type.unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
wine_df["volatile acidity"].mean()
# Out:
# 0.33969101556480197

# %% [markdown]
# ### Maps

# %%
acidity_mean = wine_df["volatile acidity"].mean()
wine_df["volatile acidity"].map(lambda p: p - acidity_mean) # Point based
# Out:
# 0      -0.069691
# 1      -0.039691
# 2      -0.059691
# 3      -0.109691
# 4      -0.109691
#           ...
# 6492    0.260309
# 6493    0.210309
# 6494    0.170309
# 6495    0.305309
# 6496   -0.029691
# Name: volatile acidity, Length: 6497, dtype: float64

# %%
def threshold_points(row):
  row["volatile acidity"] = row["volatile acidity"] - acidity_mean
  
  return row

# %%
wine_df.apply(threshold_points, axis=1)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0         -0.069691         0.36            20.7
# 1     white            6.3         -0.039691         0.34             1.6
# 2     white            8.1         -0.059691         0.40             6.9
# 3     white            7.2         -0.109691         0.32             8.5
# 4     white            7.2         -0.109691         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2          0.260309         0.08             2.0
# 6493    red            5.9          0.210309         0.10             2.2
# 6494    red            6.3          0.170309         0.13             2.3
# 6495    red            5.9          0.305309         0.12             2.0
# 6496    red            6.0         -0.029691         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
# Both apply and map return new dataframes, do not modify the original ones

# %% [markdown]
# ### Groupby

# %%
wine_df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.329348          0.389768     0.307721        5.804116
# 6             7.178037          0.313731     0.323786        5.551182
# 7             7.128962          0.288895     0.334764        4.733952
# 8             6.838542          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.060158            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054168            31.165021            115.410790  0.994558
# 7         0.045272            30.422150            108.498610  0.993126
# 8         0.041124            34.533679            117.518135  0.992514
# 9         0.027400            33.400000            116.000000  0.991460
#
#                pH  sulphates    alcohol
# quality
# 3        3.257667   0.506333  10.215000
# 4        3.231620   0.504884  10.180093
# 5        3.212042   0.526416   9.837783
# 6        3.217701   0.532466  10.587553
# 7        3.227790   0.547025  11.386006
# 8        3.223212   0.512487  11.678756
# 9        3.308000   0.466000  12.180000

# %%
wine_df.groupby('quality').sum()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3               235.60            15.510         8.43           154.2
# 4              1574.40            98.920        58.82           897.2
# 5             15633.50           832.545       657.60         12409.2
# 6             20328.20           888.485       917.61         15737.6
# 7              7692.15           311.140       361.21          5103.2
# 8              1313.00            56.165        64.18          1038.9
# 9                37.10             1.490         1.93            20.6
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# quality
# 3            2.311               1176.5                3661.0    29.872320
# 4           12.934               4457.5               22341.5   214.883850
# 5          138.256              64647.5              258354.0  2129.125135
# 6          153.566              88384.0              327305.0  2820.567455
# 7           48.849              32825.5              117070.0  1071.582860
# 8            7.937               6665.0               22681.0   191.555110
# 9            0.137                167.0                 580.0     4.957300
#
#               pH  sulphates   alcohol
# quality
# 3          97.73      15.19    306.45
# 4         698.03     108.55   2198.90
# 5        6857.71    1124.95  21033.18
# 6        9112.53    1509.01  30026.30
# 7        3476.33     590.24  12285.50
# 8         622.08      98.91   2254.00
# 9          16.54       2.33     60.90

# %% [markdown]
# ### Sorting

# %%
wine_df.sort_values(by='fixed acidity')
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4259  white            3.8             0.310         0.02            11.1
# 4787  white            3.9             0.225         0.40             4.2
# 3265  white            4.2             0.215         0.23             5.1
# 2872  white            4.2             0.170         0.36             1.8
# 4847  white            4.4             0.540         0.09             5.1
# ...     ...            ...               ...          ...             ...
# 518   white            NaN             0.130         0.28             1.9
# 1079  white            NaN               NaN         0.29             6.2
# 2902  white            NaN             0.360         0.14             8.9
# 6428    red            NaN             0.440         0.09             2.2
# 6429    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 4259      0.036                 20.0                 114.0  0.99248  3.75
# 4787      0.030                 29.0                 118.0  0.98900  3.57
# 3265      0.041                 64.0                 157.0  0.99688  3.42
# 2872      0.029                 93.0                 161.0  0.98999  3.65
# 4847      0.038                 52.0                  97.0  0.99022  3.41
# ...         ...                  ...                   ...      ...   ...
# 518       0.050                 20.0                  78.0  0.99180  3.43
# 1079      0.046                 29.0                 227.0  0.99520  3.29
# 2902      0.036                 38.0                 155.0  0.99622  3.27
# 6428      0.063                  9.0                  18.0  0.99444   NaN
# 6429      0.081                 13.0                  28.0  0.99631   NaN
#
#       sulphates  alcohol  quality
# 4259       0.44     12.4        6
# 4787       0.36     12.8        8
# 3265       0.44      8.0        3
# 2872       0.89     12.0        7
# 4847       0.40     12.2        7
# ...         ...      ...      ...
# 518        0.64     10.8        6
# 1079       0.53     10.1        6
# 2902        NaN      9.4        5
# 6428       0.69     11.3        6
# 6429       0.66     10.2        5
#
# [6497 rows x 13 columns]

# %%
sorted_wine_df = wine_df.sort_values(by='fixed acidity')

# %%
sorted_wine_df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4259  white            3.8             0.310         0.02            11.1
# 4787  white            3.9             0.225         0.40             4.2
# 3265  white            4.2             0.215         0.23             5.1
# 2872  white            4.2             0.170         0.36             1.8
# 4847  white            4.4             0.540         0.09             5.1
# ...     ...            ...               ...          ...             ...
# 518   white            NaN             0.130         0.28             1.9
# 1079  white            NaN               NaN         0.29             6.2
# 2902  white            NaN             0.360         0.14             8.9
# 6428    red            NaN             0.440         0.09             2.2
# 6429    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 4259      0.036                 20.0                 114.0  0.99248  3.75
# 4787      0.030                 29.0                 118.0  0.98900  3.57
# 3265      0.041                 64.0                 157.0  0.99688  3.42
# 2872      0.029                 93.0                 161.0  0.98999  3.65
# 4847      0.038                 52.0                  97.0  0.99022  3.41
# ...         ...                  ...                   ...      ...   ...
# 518       0.050                 20.0                  78.0  0.99180  3.43
# 1079      0.046                 29.0                 227.0  0.99520  3.29
# 2902      0.036                 38.0                 155.0  0.99622  3.27
# 6428      0.063                  9.0                  18.0  0.99444   NaN
# 6429      0.081                 13.0                  28.0  0.99631   NaN
#
#       sulphates  alcohol  quality
# 4259       0.44     12.4        6
# 4787       0.36     12.8        8
# 3265       0.44      8.0        3
# 2872       0.89     12.0        7
# 4847       0.40     12.2        7
# ...         ...      ...      ...
# 518        0.64     10.8        6
# 1079       0.53     10.1        6
# 2902        NaN      9.4        5
# 6428       0.69     11.3        6
# 6429       0.66     10.2        5
#
# [6497 rows x 13 columns]

# %%
wine_df["fixed acidity"].min()
# Out:
# 3.8

# %%
sorted_wine_df.reset_index()
# Out:
#       index   type  fixed acidity  volatile acidity  citric acid  \
# 0      4259  white            3.8             0.310         0.02
# 1      4787  white            3.9             0.225         0.40
# 2      3265  white            4.2             0.215         0.23
# 3      2872  white            4.2             0.170         0.36
# 4      4847  white            4.4             0.540         0.09
# ...     ...    ...            ...               ...          ...
# 6492    518  white            NaN             0.130         0.28
# 6493   1079  white            NaN               NaN         0.29
# 6494   2902  white            NaN             0.360         0.14
# 6495   6428    red            NaN             0.440         0.09
# 6496   6429    red            NaN             0.705         0.10
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0               11.1      0.036                 20.0                 114.0
# 1                4.2      0.030                 29.0                 118.0
# 2                5.1      0.041                 64.0                 157.0
# 3                1.8      0.029                 93.0                 161.0
# 4                5.1      0.038                 52.0                  97.0
# ...              ...        ...                  ...                   ...
# 6492             1.9      0.050                 20.0                  78.0
# 6493             6.2      0.046                 29.0                 227.0
# 6494             8.9      0.036                 38.0                 155.0
# 6495             2.2      0.063                  9.0                  18.0
# 6496             2.8      0.081                 13.0                  28.0
#
#       density    pH  sulphates  alcohol  quality
# 0     0.99248  3.75       0.44     12.4        6
# 1     0.98900  3.57       0.36     12.8        8
# 2     0.99688  3.42       0.44      8.0        3
# 3     0.98999  3.65       0.89     12.0        7
# 4     0.99022  3.41       0.40     12.2        7
# ...       ...   ...        ...      ...      ...
# 6492  0.99180  3.43       0.64     10.8        6
# 6493  0.99520  3.29       0.53     10.1        6
# 6494  0.99622  3.27        NaN      9.4        5
# 6495  0.99444   NaN       0.69     11.3        6
# 6496  0.99631   NaN       0.66     10.2        5
#
# [6497 rows x 14 columns]

# %%
sorted_wine_df.reset_index(drop=True)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            3.8             0.310         0.02            11.1
# 1     white            3.9             0.225         0.40             4.2
# 2     white            4.2             0.215         0.23             5.1
# 3     white            4.2             0.170         0.36             1.8
# 4     white            4.4             0.540         0.09             5.1
# ...     ...            ...               ...          ...             ...
# 6492  white            NaN             0.130         0.28             1.9
# 6493  white            NaN               NaN         0.29             6.2
# 6494  white            NaN             0.360         0.14             8.9
# 6495    red            NaN             0.440         0.09             2.2
# 6496    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.036                 20.0                 114.0  0.99248  3.75
# 1         0.030                 29.0                 118.0  0.98900  3.57
# 2         0.041                 64.0                 157.0  0.99688  3.42
# 3         0.029                 93.0                 161.0  0.98999  3.65
# 4         0.038                 52.0                  97.0  0.99022  3.41
# ...         ...                  ...                   ...      ...   ...
# 6492      0.050                 20.0                  78.0  0.99180  3.43
# 6493      0.046                 29.0                 227.0  0.99520  3.29
# 6494      0.036                 38.0                 155.0  0.99622  3.27
# 6495      0.063                  9.0                  18.0  0.99444   NaN
# 6496      0.081                 13.0                  28.0  0.99631   NaN
#
#       sulphates  alcohol  quality
# 0          0.44     12.4        6
# 1          0.36     12.8        8
# 2          0.44      8.0        3
# 3          0.89     12.0        7
# 4          0.40     12.2        7
# ...         ...      ...      ...
# 6492       0.64     10.8        6
# 6493       0.53     10.1        6
# 6494        NaN      9.4        5
# 6495       0.69     11.3        6
# 6496       0.66     10.2        5
#
# [6497 rows x 13 columns]

# %% [markdown]
# ### Handling Data Types and Missing Values

# %%
sorted_wine_df["free sulfur dioxide"].dtype
# Out:
# dtype('float64')

# %%
sorted_wine_df["free sulfur dioxide"].astype("int64")
# Out:
# 4259    20
# 4787    29
# 3265    64
# 2872    93
# 4847    52
#         ..
# 518     20
# 1079    29
# 2902    38
# 6428     9
# 6429    13
# Name: free sulfur dioxide, Length: 6497, dtype: int64

# %%
wine_df.dropna()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6491       0.82      9.5        6
# 6492       0.58     10.5        5
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6463 rows x 13 columns]

# %%
wine_df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
wine_df[wine_df["fixed acidity"].isnull()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 17    white            NaN             0.660         0.48             1.2
# 174   white            NaN             0.270         0.31            17.7
# 249   white            NaN             0.410         0.14            10.4
# 267   white            NaN             0.580         0.07             6.9
# 368   white            NaN             0.290         0.48             2.3
# 518   white            NaN             0.130         0.28             1.9
# 1079  white            NaN               NaN         0.29             6.2
# 2902  white            NaN             0.360         0.14             8.9
# 6428    red            NaN             0.440         0.09             2.2
# 6429    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 17        0.029                 29.0                  75.0  0.98920  3.33
# 174       0.051                 33.0                 173.0  0.99900  3.09
# 249       0.037                 18.0                 119.0  0.99600  3.38
# 267       0.043                 34.0                 149.0  0.99440  3.34
# 368       0.049                 36.0                 178.0  0.99310  3.17
# 518       0.050                 20.0                  78.0  0.99180  3.43
# 1079      0.046                 29.0                 227.0  0.99520  3.29
# 2902      0.036                 38.0                 155.0  0.99622  3.27
# 6428      0.063                  9.0                  18.0  0.99444   NaN
# 6429      0.081                 13.0                  28.0  0.99631   NaN
#
#       sulphates  alcohol  quality
# 17         0.39     12.8        8
# 174        0.64     10.2        5
# 249        0.45     10.0        5
# 267        0.57      9.7        5
# 368        0.64     10.6        6
# 518        0.64     10.8        6
# 1079       0.53     10.1        6
# 2902        NaN      9.4        5
# 6428       0.69     11.3        6
# 6429       0.66     10.2        5

# %%
mean_acidity = wine_df["fixed acidity"].mean()

# %%
mean_acidity
# Out:
# 7.2165793124710955

# %%
wine_df["fixed acidity"].fillna(value=mean_acidity, inplace=True)

# %%
wine_df.loc[17]
# Out:
# type                       white
# fixed acidity           7.216579
# volatile acidity            0.66
# citric acid                 0.48
# residual sugar               1.2
# chlorides                  0.029
# free sulfur dioxide         29.0
# total sulfur dioxide        75.0
# density                   0.9892
# pH                          3.33
# sulphates                   0.39
# alcohol                     12.8
# quality                        8
# Name: 17, dtype: object

# %% [markdown]
# ### Combining Dataframes

# %%
pd.concat([df, wine_df])
# Out:
#              Classes      Schools  Seniority   type  fixed acidity  \
# a                 AI           CS     Junior    NaN            NaN
# b              Stats        Maths     Senior    NaN            NaN
# c     Thermodynamics  Engineering  Sophomore    NaN            NaN
# 0                NaN          NaN        NaN  white            7.0
# 1                NaN          NaN        NaN  white            6.3
# ...              ...          ...        ...    ...            ...
# 6492             NaN          NaN        NaN    red            6.2
# 6493             NaN          NaN        NaN    red            5.9
# 6494             NaN          NaN        NaN    red            6.3
# 6495             NaN          NaN        NaN    red            5.9
# 6496             NaN          NaN        NaN    red            6.0
#
#       volatile acidity  citric acid  residual sugar  chlorides  \
# a                  NaN          NaN             NaN        NaN
# b                  NaN          NaN             NaN        NaN
# c                  NaN          NaN             NaN        NaN
# 0                0.270         0.36            20.7      0.045
# 1                0.300         0.34             1.6      0.049
# ...                ...          ...             ...        ...
# 6492             0.600         0.08             2.0      0.090
# 6493             0.550         0.10             2.2      0.062
# 6494             0.510         0.13             2.3      0.076
# 6495             0.645         0.12             2.0      0.075
# 6496             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# a                     NaN                   NaN      NaN   NaN        NaN
# b                     NaN                   NaN      NaN   NaN        NaN
# c                     NaN                   NaN      NaN   NaN        NaN
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# ...                   ...                   ...      ...   ...        ...
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6493                 39.0                  51.0  0.99512  3.52        NaN
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# a         NaN      NaN
# b         NaN      NaN
# c         NaN      NaN
# 0         8.8      6.0
# 1         9.5      6.0
# ...       ...      ...
# 6492     10.5      5.0
# 6493     11.2      6.0
# 6494     11.0      6.0
# 6495     10.2      5.0
# 6496     11.0      6.0
#
# [6500 rows x 16 columns]

# %%
data_dict_1 = {
    "Classes" : ["AI", "Stats", "Thermodynamics"],
    "Schools": ["CS", "Maths", "Engineering"],
    }

df_1 = pd.DataFrame(data_dict_1)

data_dict_2 = {
    "Seniority": ["Junior", "Senior", "Sophomore"]    
    }

df_2 = pd.DataFrame(data_dict_2)

# %%
df_1
# Out:
#           Classes      Schools
# 0              AI           CS
# 1           Stats        Maths
# 2  Thermodynamics  Engineering

# %%
df_2
# Out:
#    Seniority
# 0     Junior
# 1     Senior
# 2  Sophomore

# %%
df_1.join(df_2)
# Out:
#           Classes      Schools  Seniority
# 0              AI           CS     Junior
# 1           Stats        Maths     Senior
# 2  Thermodynamics  Engineering  Sophomore

# %% [markdown]
# ## Time to test your knowledge!

# %% [markdown]
# ### Question 1 - Groupby, Summary functions, Indexing

# %% [markdown]
# Suppose you are a shopkeeper who sells wine. You have a limited amount of money to buy new stock. In order to decide what quality and alcohol percentage wine to buy, you want to figure out what quality of wine sold the most, and for that, quality, what the average alcohol percentage was.
#
# Steps
# 1. Figure out which quality of wine sold the most. (*Hint: count(), groupby()*)
# 2. Filter out the relevant portion of the dataset. (*Hint: Boolean indexing*)
# 3. Find average value for the "alcohol" column. (*Hint: mean()*)

# %% [markdown]
# ## What's next?
#
# - Kaggle course: https://www.kaggle.com/learn/pandas
# - Pandas docs: https://pandas.pydata.org/docs/
#
#
# ## Next session on Wednesday, 2nd November
# - Basic Machine Learning concepts
#
# ## Future sessions
# - Intermediate machine learning
